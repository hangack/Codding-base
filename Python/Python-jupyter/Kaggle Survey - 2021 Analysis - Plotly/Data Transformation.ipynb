# %%
import numpy as np
import pandas as pd

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv("D:/_Bdata/Codding-base-Python/Python/Python-jupyter/Kaggle Survey - 2021 Analysis - Plotly/kaggle_survey_2021_responses.csv")
df_col_name = df.columns[1:]
# df.iloc[0:2, ]
# df.iloc[0:2, ].T
#questions = df.iloc[0, :].T
#print(questions.T)
#print(questions)

# %% [markdown]
# list 내부에 반복문, 조건문 그리고 비교 연산자를 넣어 필요한 값을 리스트 타입으로 뽑아낸다.

# %%
def input_num():
    print("input Question no.: ")
    Qnum = input()
    Qnum_subQ = [s for s in df_col_name if "Q"+Qnum+"_" in s]
    
    if [s for s in Qnum_subQ if ("A"or"B") in s]:
        print("input Q"+Qnum+"'s type")
        Question_type = input().upper()
        
    if Qnum_subQ:
        print("input Q"+Qnum+"'s last part no.: ")
        part_num = input()
    
    
    return questions_count(Qnum,part_num,Question_type)

# %%
def questions_count(question_num, part_num, Question_type = None):
    part_questions = []
    
    if Question_type  in ["A","B"]:
        part_questions = ['Q'+question_num+"_"+Question_type+"_Part_"+str(j) for j in range(1,int(part_num))]
        part_questions.append("Q"+question_num+"_"+Question_type+"_OTHER")
    else:
        part_questions = ['Q'+question_num+'_Part_'+str(j) for j in range(1,int(part_num))]
        part_questions.append('Q'+question_num+'_OTHER')
        
    categories = []
    counts = []
    for i in part_questions:
        category = df[i].value_counts().index[0]
        val = df[i].value_counts()[0]
        categories.append(category)
        counts.append(val)
        
    combined_df = pd.DataFrame()
    combined_df['Category'] = categories
    combined_df['Count'] = counts
    
    combined_df = combined_df.sort_values(['Count'], ascending = False)
    return combined_df

# %%
test = input_num()
# Out:
# input Question no.:
# 27
# input Q27's type
# a
# input Q27's last part no.:
# 12

# %%
test
# Out:
#                          Category  Count
# 0      Amazon Web Services (AWS)    3721
# 2    Google Cloud Platform (GCP)    3142
# 10                           None   2689
# 1                Microsoft Azure    2450
# 3            IBM Cloud / Red Hat     572
# 4                   Oracle Cloud     454
# 7                   VMware Cloud     390
# 11                          Other    337
# 5                      SAP Cloud     290
# 6               Salesforce Cloud     275
# 8                  Alibaba Cloud     259
# 9                  Tencent Cloud     172

# %%
questions_count(38,11,'A')
# Out:
#                   Category  Count
# 4             TensorBoard    1726
# 9                  MLflow    1067
# 1        Weights & Biases     538
# 10                   Other    225
# 0              Neptune.ai     217
# 7                 ClearML     177
# 5                Guild.ai     119
# 6                Polyaxon     110
# 2                Comet.ml     106
# 3      Sacred + Omniboard      98
# 8    Domino Model Monitor      91

# %%
if [s for s in questions if (("Q"+Qnum) and ("A"or"B")) in s]:
    print("import Q"+Qnum+"'s Question type: ")
    Q_tpye = input().upper()
print("import Q"+Qnum+"'s last part no.: ")
part_num = input()

# %%
def sub_questions_count(Qnum, part_num, Q_type = None):
    if Q_type in ["A","B"]

# %%
f = open("2021 Kaggle Machine Learning & Data Science Survey.txt", 'w')
#data = str(df.loc[0,:].value_counts().index)
data = df.loc[0,:].value_counts().index.tolist()
for i in data:
#    s = str(data[i])
    f.write(i+"\n")
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
df.loc[0,:].value_counts().index.tolist()
# Out:
# ['Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis? (Select all that apply) - Selected Choice - MongoDB ',
#  'In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice',
#  'Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years? (Select all that apply) - Selected Choice - Oracle Database ',
#  'Which of the following hosted notebook products do you use on a regular basis?  (Select all that apply) - Selected Choice -  Kaggle Notebooks',
#  'Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis?  (Select all that apply) - Selected Choice - Other',
# ...

# %% [markdown]
# ### 참조
#  - https://www.kaggle.com/j2hoon85/for-newbie-let-s-do-data-transformation
#  - https://lapina.tistory.com/108
