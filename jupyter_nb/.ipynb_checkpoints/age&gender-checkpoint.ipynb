# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from warnings import filterwarnings
filterwarnings('ignore')
colors = ['#B1EDED','#B1B2ED','#1DE7ED','#1DA5ED','#1D50ED','#16548E']

# %%
df = pd.read_csv("D:/_Bdata/Codding-base-Python/Python/Python-jupyter/Kaggle Survey - 2021 Analysis - Plotly/kaggle_survey_2021_responses.csv")
df.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                  Bachelor’s degree
# 2                                    Master’s degree
# 3                                    Master’s degree
# 4                                    Doctoral degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                              Other
# 2                            Program/Project Manager
# 3                                  Software Engineer
# 4                                 Research Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                          20+ years
# 3                                          1-3 years
# 4                                          20+ years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                                NaN
# 3                                             Python
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                NaN  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                         Q38_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                       TensorBoard
# 4                                                NaN
#
#                                         Q38_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_11  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                               None
# 3                                                NaN
# 4                                               None
#
#                                          Q38_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 369 columns]

# %%
df = df[df.Q3.isin(["Japan","China"])]
print(df.shape)
df.sample(5)
# Out:
# (1735, 369)
#       Time from Start to Finish (seconds)     Q1   Q2     Q3  \
# 19938                                 221  25-29  Man  Japan
# 14480                                 148  18-21  Man  Japan
# 19132                                 457  25-29  Man  China
# 22641                                 425  22-24  Man  Japan
# 18146                                 674  35-39  Man  Japan
#
#                       Q4                 Q5           Q6 Q7_Part_1 Q7_Part_2  \
# 19938    Master’s degree  Software Engineer    3-5 years    Python       NaN
# 14480  Bachelor’s degree            Student    3-5 years       NaN       NaN
# 19132    Master’s degree            Student    3-5 years    Python       NaN
# 22641    Master’s degree            Student    3-5 years    Python       NaN
# 18146  Bachelor’s degree  Software Engineer  10-20 years    Python       NaN
#
#       Q7_Part_3  ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# 19938       NaN  ...          NaN          NaN            NaN          NaN
# 14480       NaN  ...          NaN          NaN            NaN          NaN
# 19132       NaN  ...    Comet.ml           NaN   TensorBoard           NaN
# 22641       NaN  ...          NaN          NaN            NaN          NaN
# 18146       NaN  ...          NaN          NaN            NaN          NaN
#
#       Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11  \
# 19938          NaN          NaN          NaN           NaN           NaN
# 14480          NaN          NaN          NaN           NaN           NaN
# 19132          NaN          NaN          NaN           NaN           NaN
# 22641          NaN          NaN          NaN           NaN          None
# 18146          NaN          NaN          NaN           NaN           NaN
#
#       Q38_B_OTHER
# 19938         NaN
# 14480         NaN
# 19132         NaN
# 22641         NaN
# 18146         NaN
#
# [5 rows x 369 columns]

# %%
df_ch_sort = df_ch['Q1'].value_counts().sort_index()
df_ja_sort = df_ja['Q1'].value_counts().sort_index()

fig = go.Figure(data=[
    go.Bar(name='China', x=df_ch_sort.index, y=df_ch_sort.values, marker_color=colors[2]),
    go.Bar(name='Japan', x=df_ja_sort.index, y=df_ja_sort.values, marker_color=colors[3])
])


fig.update_layout(barmode='group', title='China & Japan Age', xaxis_title='Age', yaxis_title='Counts')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9ae16db182c3> in <module>
# ----> 1 df_ch_sort = df_ch['Q1'].value_counts().sort_index()
#       2 df_ja_sort = df_ja['Q1'].value_counts().sort_index()
#       3
#       4 fig = go.Figure(data=[
#       5     go.Bar(name='China', x=df_ch_sort.index, y=df_ch_sort.values, marker_color=colors[2]),
#
# NameError: name 'df_ch' is not defined
