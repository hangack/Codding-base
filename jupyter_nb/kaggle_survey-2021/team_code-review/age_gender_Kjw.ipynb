# %% [markdown]
# 참고 : https://www.kaggle.com/venky73/usa-vs-india-working-professionals
#        https://www.kaggle.com/j2hoon85/plotly-tutorial-for-kaggle-survey-competitions

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns

#df = pd.read_csv("C:/Users/rudal/kaggle_survey_2021_responses.csv",low_memory=False)
df = pd.read_csv("D:/_Bdata/Codding-base-Python/Python/Python-jupyter/Kaggle Survey - 2021 Analysis - Plotly/kaggle_survey_2021_responses.csv")

df.sample(5)

colors = ['rebeccapurple','steelblue','darktyrquoise','tyrquoise','yellowgreen','#9C009C']
# Out:
# D:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.shape
# Out:
# (25974, 369)

# %%
print(df)
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                     910                        50-54
# 2                                     784                        50-54
# 3                                     924                        22-24
# 4                                     575                        45-49
# ...                                   ...                          ...
# 25969                                1756                        30-34
# 25970                                 253                        22-24
# 25971                                 494                        50-54
# 25972                                 277                        45-49
# 25973                                 255                        18-21
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
fig_j = go.Figure(data=[go.Pie(labels=df_Jp['Q2'][1:].value_counts().index, 
                               values=df_Jp['Q2'][1:].value_counts().values,
#                               pull=[0,0,0.4,0.8,0.8],
                               textinfo ='label,percent',
                               title='Japan',
                               hole=0.3)])

fig_j.update_traces(marker=dict(colors=colors[1:]))
fig_j.update_layout(title_text='Gender')


fig_c = go.Figure(data=[go.Pie(labels=df_Ch['Q2'][1:].value_counts().index, 
                               values=df_Ch['Q2'][1:].value_counts().values,
#                               pull=[0,0,0.4,0.8,0.8],
                               textinfo ='label,percent',
                               title='China',
                               hole=0.3)])

fig_c.update_traces(marker=dict(colors=colors[1:]))
fig_c.update_layout(title_text='Gender')


fig_j.show()
fig_c.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1b210d81f1ae> in <module>
# ----> 1 fig_j = go.Figure(data=[go.Pie(labels=df_Jp['Q2'][1:].value_counts().index,
#       2                                values=df_Jp['Q2'][1:].value_counts().values,
#       3 #                               pull=[0,0,0.4,0.8,0.8],
#       4                                textinfo ='label,percent',
#       5                                title='Japan',
#
# NameError: name 'df_Jp' is not defined

# %%
df_Jp_sortAge = df_Jp['Q1'].value_counts().sort_index()
df_Ch_sortAge = df_Ch['Q1'].value_counts().sort_index()

# %%
fig = go.Figure(data=[go.Bar(name='Japan', 
                             x=df_Jp_sortAge.index, 
                             y=df_Jp_sortAge.values,
                             marker_color = colors[1]
                             ),
                      go.Bar(name='China', 
                             x=df_Ch_sortAge.index, 
                             y=df_Ch_sortAge.values,
                             marker_color = colors[0])])

fig.update_layout(title='Age: Japan & China',
                 xaxis_title="Age", yaxis_title='Counts')

fig.show()
